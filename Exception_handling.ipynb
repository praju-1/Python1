# %%
"hello"
# Out:
# 'hello'

# %%
a = 10
a
# Out:
# 10

# %%
"good morning"
# Out:
# 'good morning'

# %%
# try
# except
# finally

# %%
a = 10
b = 0
try:
    print(a/b)
except Exception as e:
    print(e)
finally:
    print("This always execute")
# Out:
# division by zero
# This always execute

# %%
"good morning"
# Out:
# 'good morning'

# %%
a = 10
b= 2
try:
    print(a/b)
    try:
        f = open('abc.txt', 'r')
        f.write("Hello")
        print("File is updated")
    except Exception as e:
        print(e)
except Exception as e:
    print(e)
# Out:
# 5.0
# not writable

# %%
def calculation():
    a = 10
    b= 2
    try:
        print(a/b)
        try:
            f = open('abc.txt', 'r')
            f.write("Hello")
            print("File is updated")
        except Exception as e:
            print(e)
    except Exception as e:
        print(e)

# %%
calculation()
# Out:
# 5.0
# not writable
