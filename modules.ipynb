# %%
#pip install numpy

# %%
import random

# %%
from random import *

# %%
random()
# Out:
# 0.23747964019247958

# %%
random()
# Out:
# 0.41081338375676024

# %%
for i in range(5):
    print(random())
# Out:
# 0.5021438224545837
# 0.5140359690999331
# 0.3786925454360085
# 0.6039620302070089
# 0.5418067670126386

# %%
randint(1, 10)
# Out:
# 10

# %%
for i in range(5):
    print(randint(1, 10))
# Out:
# 9
# 7
# 2
# 7
# 8

# %%
randrange(10, 100, 5)
# Out:
# 95

# %%
uniform(1, 10)
# Out:
# 5.8030900682702296

# %%
l = [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
choice(l)
# Out:
# 3

# %%
sample(l,k=3)
# Out:
# [4, 5, 1]
